# %%
# %%capture

from google.colab import drive
drive.mount('/content/drive')

# !pip install FrEIA
# %cd /content/drive/MyDrive/Trial1/hvs_hsi_pytorch_colab
# !pip install -e .

# %cd /content/drive/MyDrive/Trial1/HVS_INN_MC_Project_colab

# %%
# %%time
# !python src/cuda_main.py

# %%
# !python src/sto2_estimation_batch_finger.py
# Out:
# 100%|################################################################| 4/4 [08:58<00:00, 134.54s/it]

# %%
# !python src/sto2_estimation_batch_colon.py

# %%
# !python src/sto2_estimation_batch_pig.py
