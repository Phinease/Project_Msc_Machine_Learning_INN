# %% [markdown]
# # HSI image StO2 estimation on INN model

# %% [markdown]
# ## Preparation

# %%
# %%capture

from google.colab import drive
drive.mount('/content/drive')

# !pip install FrEIA
# %cd /content/drive/MyDrive/Trial1/hvs_hsi_pytorch_colab
# !pip install -e .

# %cd /content/drive/MyDrive/Trial1/HVS_INN_MC_Project_colab

# %%
# %matplotlib notebook
name_model = "model_pig_1"
c = None
exec('import models.' + name_model + "_config as c")

from src.inn_model import *
from src.dataset import *
from src.visualisation import *
from tqdm import tqdm

import glob
import copy
import torch
import pandas as pd
import numpy as np

from hvs_hsi_pytorch.utils import hsi_utils, utils
from hvs_hsi_pytorch.hs_image import HSImage

# %%
# Read reformatted dataset
data_colon = pd.read_csv("data/mc/generic_train_15.7.15.4_power_led_300.csv")
train_df = data_colon[:int(len(data_colon) * 0.9)]

# Data loader
train_dataset = McDataset(train_df, c)
train_loader = data_utils.DataLoader(train_dataset, batch_size=c.batch_size, shuffle=True, drop_last=True)

# Set up dimensionality
c.ndim_y = train_dataset.get_y_dim()
c.ndim_x = train_dataset.get_x_dim()
c.ndim_tot = max(c.ndim_y, c.ndim_x) + c.ndim_z

# Model
model = inn_model(c)
model.load_state_dict(torch.load('models/' + name_model, map_location=torch.device(c.device)))
_ = model.eval()

# %%
# Read HSI image data
img_files = glob.glob("data/raw/*")
n_files, i_files = len(img_files), 0
for i in range(len(img_files)):
    print(('[*]' if i == i_files or i == n_files + i_files else '[ ]') + '\t%s' % (img_files[i].split('/')[-1]))

img_path = img_files[i_files]
img = hsi_utils.load_frame(img_path, bitshift=False)

hsi_data = HSImage(array=img, wavelengths=None, camera="imec 4x4-VIS-15.7.15.4")
hsi_data.reconstruct(white=None, dark=None,  rho=0.88, lightsource='d_light_c', method='spectral')
hsi_origin = copy.deepcopy(hsi_data)
hsi_data.array = utils.normalise_L1(hsi_data.array)
# Out:
# [*]	frame_012529_raw.png
# [ ]	frame_012665_raw.png
# [ ]	frame_012559_raw.png
# [ ]	frame_012544_raw.png
# [ ]	frame_012669_raw.png
# [ ]	frame_012610_raw.png
# [ ]	frame_012695_raw.png
# [ ]	frame_012601_raw.png
# [ ]	frame_012555_raw.png
# [ ]	frame_012629_raw.png
# [ ]	frame_012742_raw.png
# [ ]	frame_012598_raw.png
# [ ]	frame_012603_raw.png
# [ ]	frame_012637_raw.png
# [ ]	frame_012631_raw.png
# [ ]	frame_012718_raw.png
# [ ]	frame_012635_raw.png
# [ ]	frame_012519_raw.png
# [ ]	frame_012650_raw.png
# [ ]	frame_012545_raw.png
# [ ]	frame_012579_raw.png
# [ ]	frame_012639_raw.png
# [ ]	frame_012542_raw.png
# [ ]	frame_012516_raw.png
# [ ]	frame_012729_raw.png
# [ ]	frame_012652_raw.png
# [ ]	frame_012715_raw.png
# [ ]	frame_012699_raw.png
# [ ]	frame_012698_raw.png
# [ ]	frame_012538_raw.png
# [ ]	frame_012580_raw.png
# [ ]	frame_012585_raw.png
# [ ]	frame_012524_raw.png
# [ ]	frame_012658_raw.png
# [ ]	frame_012556_raw.png
# [ ]	frame_012643_raw.png
# [ ]	frame_012664_raw.png
# [ ]	frame_012725_raw.png
# [ ]	frame_012566_raw.png
# [ ]	frame_012670_raw.png
# [ ]	frame_012711_raw.png
# [ ]	frame_012530_raw.png
# [ ]	frame_012744_raw.png
# [ ]	frame_012740_raw.png
# [ ]	frame_012596_raw.png
# [ ]	frame_012564_raw.png
# [ ]	frame_012570_raw.png
# [ ]	frame_012630_raw.png
# [ ]	frame_012582_raw.png
# [ ]	frame_012632_raw.png
# [ ]	frame_012680_raw.png
# [ ]	frame_012675_raw.png
# [ ]	frame_012600_raw.png
# [ ]	frame_012678_raw.png
# [ ]	frame_012512_raw.png
# [ ]	frame_012591_raw.png
# [ ]	frame_012592_raw.png
# [ ]	frame_012690_raw.png
# [ ]	frame_012731_raw.png
# [ ]	frame_012685_raw.png
# [ ]	frame_012511_raw.png
# [ ]	frame_012712_raw.png
# [ ]	frame_012745_raw.png
# [ ]	frame_012741_raw.png
# [ ]	frame_012508_raw.png
# [ ]	frame_012679_raw.png
# [ ]	frame_012651_raw.png
# [ ]	frame_012756_raw.png
# [ ]	frame_012572_raw.png
# [ ]	frame_012541_raw.png
# [ ]	frame_012688_raw.png
# [ ]	frame_012672_raw.png
# [ ]	frame_012561_raw.png
# [ ]	frame_000000_raw.png
# [ ]	frame_012649_raw.png
# [ ]	frame_012608_raw.png
# [ ]	frame_012587_raw.png
# [ ]	frame_012514_raw.png
# [ ]	frame_012752_raw.png
# [ ]	frame_012586_raw.png
# [ ]	frame_012615_raw.png
# [ ]	frame_012727_raw.png
# [ ]	frame_012747_raw.png
# [ ]	frame_012550_raw.png
# [ ]	frame_012704_raw.png
# [ ]	frame_012668_raw.png
# [ ]	frame_012537_raw.png
# [ ]	frame_012525_raw.png
# [ ]	frame_012719_raw.png
# [ ]	frame_012697_raw.png
# [ ]	frame_012552_raw.png
# [ ]	frame_012692_raw.png
# [ ]	frame_012677_raw.png
# [ ]	frame_012738_raw.png
# [ ]	frame_012702_raw.png
# [ ]	frame_012743_raw.png
# [ ]	frame_012549_raw.png
# [ ]	frame_012696_raw.png
# [ ]	frame_012645_raw.png
# [ ]	frame_012562_raw.png
# [ ]	frame_012749_raw.png
# [ ]	frame_012575_raw.png
# [ ]	frame_012734_raw.png
# [ ]	frame_012565_raw.png
# [ ]	frame_012653_raw.png
# [ ]	frame_012571_raw.png
# [ ]	frame_012640_raw.png
# [ ]	frame_012568_raw.png
# [ ]	frame_012503_raw.png
# [ ]	frame_012532_raw.png
# [ ]	frame_012674_raw.png
# [ ]	frame_012613_raw.png
# [ ]	frame_012515_raw.png
# [ ]	frame_012560_raw.png
# [ ]	frame_012686_raw.png
# [ ]	frame_012714_raw.png
# [ ]	frame_012620_raw.png
# [ ]	frame_012599_raw.png
# [ ]	frame_012691_raw.png
# [ ]	frame_012584_raw.png
# [ ]	frame_012750_raw.png
# [ ]	frame_012710_raw.png
# [ ]	frame_012536_raw.png
# [ ]	frame_012576_raw.png
# [ ]	frame_012577_raw.png
# [ ]	frame_012760_raw.png
# [ ]	frame_012708_raw.png
# [ ]	frame_012521_raw.png
# [ ]	frame_012766_raw.png
# [ ]	frame_012667_raw.png
# [ ]	frame_012589_raw.png
# [ ]	frame_012746_raw.png
# [ ]	frame_012604_raw.png
# [ ]	frame_012546_raw.png
# [ ]	frame_012673_raw.png
# [ ]	frame_012513_raw.png
# [ ]	frame_012534_raw.png
# [ ]	frame_012531_raw.png
# [ ]	frame_012753_raw.png
# [ ]	frame_012563_raw.png
# [ ]	frame_012583_raw.png
# [ ]	frame_012762_raw.png
# [ ]	frame_012761_raw.png
# [ ]	frame_012618_raw.png
# [ ]	frame_012612_raw.png
# [ ]	frame_012737_raw.png
# [ ]	frame_012547_raw.png
# [ ]	frame_012588_raw.png
# [ ]	frame_012660_raw.png
# [ ]	frame_012551_raw.png
# [ ]	frame_012636_raw.png
# [ ]	frame_012548_raw.png
# [ ]	frame_012671_raw.png
# [ ]	frame_012558_raw.png
# [ ]	frame_012758_raw.png
# [ ]	frame_012659_raw.png
# [ ]	frame_012663_raw.png
# [ ]	frame_012755_raw.png
# [ ]	frame_012628_raw.png
# [ ]	frame_012646_raw.png
# [ ]	frame_012557_raw.png
# [ ]	frame_012713_raw.png
# [ ]	frame_012609_raw.png
# [ ]	frame_012602_raw.png
# [ ]	frame_012666_raw.png
# [ ]	frame_012754_raw.png
# [ ]	frame_012687_raw.png
# [ ]	frame_012763_raw.png
# [ ]	frame_012624_raw.png
# [ ]	frame_012597_raw.png
# [ ]	frame_012543_raw.png
# [ ]	frame_012642_raw.png
# [ ]	frame_012764_raw.png
# [ ]	frame_012518_raw.png
# [ ]	frame_012662_raw.png
# [ ]	frame_012728_raw.png
# [ ]	frame_012735_raw.png
# [ ]	frame_012578_raw.png
# [ ]	frame_012647_raw.png
# [ ]	frame_012723_raw.png
# [ ]	frame_012520_raw.png
# [ ]	frame_012522_raw.png
# [ ]	frame_012509_raw.png
# [ ]	frame_012733_raw.png
# [ ]	frame_012730_raw.png
# [ ]	frame_012724_raw.png
# [ ]	frame_012611_raw.png
# [ ]	frame_012505_raw.png
# [ ]	frame_012539_raw.png
# [ ]	frame_012569_raw.png
# [ ]	frame_012736_raw.png
# [ ]	frame_012661_raw.png
# [ ]	frame_012527_raw.png
# [ ]	frame_012638_raw.png
# [ ]	frame_012683_raw.png
# [ ]	frame_012621_raw.png
# [ ]	frame_012757_raw.png
# [ ]	frame_012523_raw.png
# [ ]	frame_012500_raw.png
# [ ]	frame_012682_raw.png
# [ ]	frame_012605_raw.png
# [ ]	frame_012634_raw.png
# [ ]	frame_012581_raw.png
# [ ]	frame_012594_raw.png
# [ ]	frame_012707_raw.png
# [ ]	frame_012590_raw.png
# [ ]	frame_012617_raw.png
# [ ]	frame_012501_raw.png
# [ ]	frame_012526_raw.png
# [ ]	frame_012633_raw.png
# [ ]	frame_012595_raw.png
# [ ]	frame_012607_raw.png
# [ ]	frame_012540_raw.png
# [ ]	frame_012627_raw.png
# [ ]	frame_012693_raw.png
# [ ]	frame_012504_raw.png
# [ ]	frame_012739_raw.png
# [ ]	frame_012574_raw.png
# [ ]	frame_012721_raw.png
# [ ]	frame_012528_raw.png
# [ ]	frame_012644_raw.png
# [ ]	frame_012533_raw.png
# [ ]	frame_012654_raw.png
# [ ]	frame_012657_raw.png
# [ ]	frame_012554_raw.png
# [ ]	frame_012689_raw.png
# [ ]	frame_012701_raw.png
# [ ]	frame_012616_raw.png
# [ ]	frame_012700_raw.png
# [ ]	frame_012759_raw.png
# [ ]	frame_012656_raw.png
# [ ]	frame_012705_raw.png
# [ ]	frame_012751_raw.png
# [ ]	frame_012567_raw.png
# [ ]	frame_012506_raw.png
# [ ]	frame_012619_raw.png
# [ ]	frame_012748_raw.png
# [ ]	frame_012717_raw.png
# [ ]	frame_012655_raw.png
# [ ]	frame_012694_raw.png
# [ ]	frame_012614_raw.png
# [ ]	frame_012720_raw.png
# [ ]	frame_012622_raw.png
# [ ]	frame_012676_raw.png
# [ ]	frame_012709_raw.png
# [ ]	frame_012726_raw.png
# [ ]	frame_012681_raw.png
# [ ]	frame_012722_raw.png
# [ ]	frame_012517_raw.png
# [ ]	frame_012765_raw.png
# [ ]	frame_012684_raw.png
# [ ]	frame_012507_raw.png
# [ ]	frame_012573_raw.png
# [ ]	frame_012502_raw.png
# [ ]	frame_012625_raw.png
# [ ]	frame_012535_raw.png
# [ ]	frame_012606_raw.png
# [ ]	frame_012716_raw.png
# [ ]	frame_012732_raw.png
# [ ]	frame_012706_raw.png
# [ ]	frame_012623_raw.png
# [ ]	frame_012510_raw.png
# [ ]	frame_012593_raw.png
# [ ]	frame_012703_raw.png
# [ ]	frame_012648_raw.png
# [ ]	frame_012553_raw.png
# [ ]	frame_012626_raw.png
# [ ]	frame_012641_raw.png
# [ ]	exported_white_2022-06-29-15-43-17.png
# [ ]	exported_white_2022-06-29-15-43-31.png
# [ ]	exported_white_2022-06-29-13-52-21.png

# %%
show_hvs_combo(hsi_origin, mask=False)

# %%
# %%time
# Data reformat
data = hsi_data.array
shape = data.shape
data = data.reshape(shape[0], shape[1] * shape[2]).swapaxes(0, 1)

step = 2 ** 13
batch = list(np.arange(data.shape[0], step=step))
batch.append(data.shape[0])

output = torch.tensor([])
for i in tqdm(range(len(batch) - 1), ascii=True, ncols=100):
    y = data[batch[i]:batch[i + 1]].to(c.device)
    z = torch.randn(y.shape[0], c.ndim_z).to(c.device)
    y = torch.cat((torch.zeros(y.shape[0], c.ndim_tot - c.ndim_y - c.ndim_z).to(c.device), y), dim=1)
    y = torch.cat((z, y), dim=1).to(c.device)
    pred_x = model(y, rev=True)[0][:, c.target].detach().cpu().clone()
    output = torch.cat((output, pred_x))

output = output.reshape(shape[1], shape[2])[:, :, None]
# Out:
# 100%|#############################################################| 272/272 [00:03<00:00, 85.91it/s]
# CPU times: user 3.1 s, sys: 65 ms, total: 3.17 s
# Wall time: 3.18 s

# %% [markdown]
# ## HVS Sto2 estimation

# %%
# show_hvs_combo(hsi_origin, mask=False)

# %%
show_inn_combo_norm(hsi_origin, output, mask=False)

# %%
show_inn_combo_origin(hsi_origin, output, mask=False, aim_range=(-0.1, 1.1))
